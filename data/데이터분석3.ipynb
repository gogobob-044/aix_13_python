# %%
import pandas as pd

scientists = pd.DataFrame(
    data={
        "Occupation": ["Chemist", "Statistician"],
        "Born": ["1920-07-25", "1876-06-13"],
        "Died": ["1958-04-16", "1937-10-16"],
        "Age": [37, 61],
    },
    index=["Rosaline Franklin", "William Gosset"],
    columns=["Occupation", "Born", "Died", "Age"],
)
print(scientists)
# Out:
#                      Occupation        Born        Died  Age
# Rosaline Franklin       Chemist  1920-07-25  1958-04-16   37
# William Gosset     Statistician  1876-06-13  1937-10-16   61

# %%
scientists.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2 entries, Rosaline Franklin to William Gosset
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Occupation  2 non-null      object
#  1   Born        2 non-null      object
#  2   Died        2 non-null      object
#  3   Age         2 non-null      int64
# dtypes: int64(1), object(3)
# memory usage: 80.0+ bytes

# %%
scientists['born_dt'] = pd.to_datetime(scientists['Born'],format='%Y-%m-%d')

# %%
scientists['died_dt'] = pd.to_datetime(scientists['Died'],format='%Y-%m-%d')

# %%
scientists.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2 entries, Rosaline Franklin to William Gosset
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Occupation  2 non-null      object
#  1   Born        2 non-null      datetime64[ns]
#  2   Died        2 non-null      datetime64[ns]
#  3   Age         2 non-null      int64
#  4   died_dt     2 non-null      datetime64[ns]
#  5   born_dt     2 non-null      datetime64[ns]
# dtypes: datetime64[ns](4), int64(1), object(1)
# memory usage: 220.0+ bytes

# %%
#생존나라ㅉ 계산
scientists['age_days'] = scientists['died_dt']-scientists['born_dt']

# %%
scientists['age_days']/365
# Out:
# Rosaline Franklin   37 days 18:00:59.178082191
# William Gosset      61 days 09:08:23.013698630
# Name: age_days, dtype: timedelta64[ns]

# %%
 scientists['born']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'born'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 scientists['born']
#
# ...

# %%
inport numpuypdNave                                                                                                                                                                                                                                                                                                                                     .to_datetime("2004-02-21")
# Out:
# Timestamp('2004-02-21 00:00:00')

# %%
'ear'scientists['age_days'].dt.daygs
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 scientists['age_days'].dt.daygs
#
# AttributeError: 'TimedeltaProperties' object has no attribute 'daygs'

# %%
df_drepped =scientists.drop('Age',axis='columns')#axis='columns'없으면 행기준
#삭제한 복사본 반환,원본 안건듦

# %%
whos
# Out:
# Variable               Type         Data/Info
# ---------------------------------------------
# dataframe_columns      function     <function dataframe_colum<...>ns at 0x00000186E10CC360>
# dataframe_hash         function     <function dataframe_hash at 0x00000186E2522660>
# df_drepped             DataFrame    Shape: (2, 6)
# dtypes_str             function     <function dtypes_str at 0x00000186E2521BC0>
# get_dataframes         function     <function get_dataframes at 0x00000186E249ADE0>
# getpass                module       <module 'getpass' from 'C<...>conda3\\Lib\\getpass.py'>
# hashlib                module       <module 'hashlib' from 'C<...>conda3\\Lib\\hashlib.py'>
# import_pandas_safely   function     <function import_pandas_s<...>ly at 0x00000186E10CC5E0>
# is_data_frame          function     <function is_data_frame at 0x00000186E10CC2C0>
# json                   module       <module 'json' from 'C:\\<...>\Lib\\json\\__init__.py'>
# ...

# %%
# df_drepped =scientists.drop('Age',axis='columns')
df_drepped =scientists.drop('Age',axis='columns', inplace=True)#원본 반영
#이게 더 빠름

# %%
scientists['Occupation'].str.upper()
# Out:
# Rosaline Franklin         CHEMIST
# William Gosset       STATISTICIAN
# Name: Occupation, dtype: object

# %%
def my_sq(x):
    '''
    입력 파라미터를 제공하는 함쉬
    '''
    return x**2

# %%
df = pd.DataFrame({
    'a':[10,20,30],
    'b':[20,30,40],
    })
df
# Out:
#     a   b
# 0  10  20
# 1  20  30
# 2  30  40

# %%
df['a'].apply(my_sq)
df['a']**2 #위아래 동일한 실행
# Out:
# 0    100
# 1    400
# 2    900
# Name: a, dtype: int64

# %%
def to_grade(x):
    if x == 10: return "A"
    if x == 20: return "B"
    return "C"

df['a'].apply(to_grade)
#숫자를 문자로 변환
# Out:
# 0    A
# 1    B
# 2    C
# Name: a, dtype: object
